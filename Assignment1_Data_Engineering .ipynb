# %% [markdown]
# Read Dataset(csv,json,parquet)

# %%
import pandas as pd

# %%
import os

# %%
import numpy as np

# %% [markdown]
# CSV file

# %%
csv_path1="D:\\fasith\\customers.csv.csv"

# %% [markdown]
# Read Datasets

# %%
import pandas as pd

# %%
df_csv1 = pd.read_csv(csv_path1)

# %%
df_csv1
# Out:
#      Index      Customer Id First Name Last Name                      Company  \
# 0        1  dE014d010c7ab0c     Andrew   Goodman                Stewart-Flynn
# 1        2  2B54172c8b65eC3      Alvin      Lane  Terry, Proctor and Lawrence
# 2        3  d794Dd48988d2ac      Jenna   Harding                 Bailey Group
# 3        4  3b3Aa4aCc68f3Be   Fernando      Ford                 Moss-Maxwell
# 4        5  D60df62ad2ae41E       Kara     Woods              Mccarthy-Kelley
# ..     ...              ...        ...       ...                          ...
# 995    996  FbcCaF483aFaFAE      Diana    Monroe                  Bass-Wilson
# 996    997  979c4D58Ae9a9cc      Jerry   Morales                   Pratt-King
# 997    998  D0DcF6a4BcefCc8     Tracie     Floyd     Holt, Wilson and Shields
# 998    999  90EE9CbbDa374E9       Paul    Barnes     Brown, Oliver and Haynes
# 999   1000  51732B5b2328015    Dominic     Duran                   Durham LLC
#
# ...

# %%
df_csv1.head()
# Out:
#    Index      Customer Id First Name Last Name                      Company  \
# 0      1  dE014d010c7ab0c     Andrew   Goodman                Stewart-Flynn
# 1      2  2B54172c8b65eC3      Alvin      Lane  Terry, Proctor and Lawrence
# 2      3  d794Dd48988d2ac      Jenna   Harding                 Bailey Group
# 3      4  3b3Aa4aCc68f3Be   Fernando      Ford                 Moss-Maxwell
# 4      5  D60df62ad2ae41E       Kara     Woods              Mccarthy-Kelley
#
#                City           Country                Phone 1  \
# 0       Rowlandberg             Macao      846-790-4623x4715
# 1          Bethside  Papua New Guinea     124-597-8652x05682
# 2      Moniquemouth             China     (335)987-3085x3780
# 3        Leeborough             Macao          (047)752-3122
# 4  Port Jacksonland             Nepal  +1-360-693-4419x19272
#
#                Phone 2                          Email Subscription Date  \
# ...

# %%
csv_path2="D:\\fasith\\organizations.csv.csv"

# %%
csv_path3="D:\\fasith\\user_profile.csv.csv"

# %%
df_csv2 = pd.read_csv(csv_path2)
df_csv3 = pd.read_csv(csv_path3)

# %%
df_csv2
# Out:
#      Index  Organization Id                       Name  \
# 0        1  E84A904909dF528                 Liu-Hoover
# 1        2  AAC4f9aBF86EAeF              Orr-Armstrong
# 2        3  ad2eb3C8C24DB87                  Gill-Lamb
# 3        4  D76BB12E5eE165B                Bauer-Weiss
# 4        5  2F31EddF2Db9aAE                Love-Palmer
# ..     ...              ...                        ...
# 995    996  e5CEc38aa9A580b              Bullock Group
# 996    997  cEF9B4675E4bBd0                  Mason Inc
# 997    998  9abEb8aaFd25E04           Houston and Sons
# 998    999  de5Fc71DE825bFc              Olson-Solomon
# 999   1000  3ddb89ecD83B533  Maddox, Owen and Shepherd
#
#                           Website                   Country  \
# 0     http://www.day-hartman.org/            Western Sahara
# 1        https://www.chapman.net/                   Algeria
# 2                 http://lin.com/             Cote d'Ivoire
# ...

# %%
df_csv3
# Out:
#      Index          User Id First Name Last Name     Sex  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    2014-01-27
# 1    fergusonkatherine@example.net        +1-950-759-8687    1931-07-26
# ...

# %% [markdown]
# JSON files

# %%
import json

# %%
import pandas as pd

# %%
json_path1="D:\\fasith\\employees.json.json"

# %% [markdown]
# Read Datasets

# %%
with open(json_path1, "r") as f:
    raw_data1 = json.load(f)

# %%
df_json1 = pd.json_normalize(raw_data1)

# %%
df_json1
# Out:
#     employee.id       employee.name                 employee.position  \
# 0        E00001         Traci Kelly               Geologist, wellsite
# 1        E00002      Thomas Mendoza               Magazine journalist
# 2        E00003    Natasha Williams                   Tourism officer
# 3        E00004        Walter Hanna                     Herpetologist
# 4        E00005     Daniel Williams                 Social researcher
# ..          ...                 ...                               ...
# 561      E00562         Bryan Davis             Volunteer coordinator
# 562      E00563    Jennifer Wiggins              Financial controller
# 563      E00564  Michael Williamson                Purchasing manager
# 564      E00565         Sharon Chan          Teacher, adult education
# 565      E00566       James Roberts  Accountant, chartered management
#
#     employee.department.id employee.department.name  \
# 0                     D006                 Monetize
# ...

# %%
json_path2="D:\\fasith\\products.json.json"

# %%
with open(json_path2, "r") as f:
    data2 = json.load(f)

# %%
df_json2 = pd.json_normalize(data2)

# %%
df_json2
# Out:
#    productId           productName  \
# 0       1001   Wireless Headphones
# 1       1002       Smartphone Case
# 2       1003  4K Ultra HD Smart TV
# 3       1004     Bluetooth Speaker
# 4       1005         Winter Jacket
#
#                                          description      brand     category  \
# 0  Noise-cancelling wireless headphones with Blue...   SoundPro  Electronics
# 1  Durable and shockproof case for smartphones, a...   CaseMate  Accessories
# 2  55-inch 4K Ultra HD Smart TV with built-in Wi-...  Visionary  Electronics
# 3  Portable Bluetooth speaker with 12-hour batter...     AudioX  Electronics
# 4  Men's water-resistant winter jacket with a fur...   ColdTech     Clothing
#
#     price currency                                             images  \
# 0  199.99      USD  [https://example.com/products/1001/main.jpg, h...
# 1   29.99      USD  [https://example.com/products/1002/main.jpg, h...
# 2  799.99      USD  [https://example.com/products/1003/main.jpg, h...
# ...

# %%
json_path3="D:\\fasith\\user_profiles.json.json"

# %%
with open(json_path3, "r") as f:
    data3 = json.load(f)

# %%
df_json3 = pd.json_normalize(data3)

# %%
df_json3
# Out:
#    userId username                email          passwordHash  \
# 0       1  johndoe  johndoe@example.com  abc123hashedpassword
# 1       2  janedoe  janedoe@example.com  xyz987hashedpassword
#
#                                         activityLogs profile.firstName  \
# 0  [{'timestamp': '2025-01-09T14:20:00Z', 'activi...              John
# 1  [{'timestamp': '2025-01-09T18:30:00Z', 'activi...              Jane
#
#   profile.lastName profile.birthDate profile.gender  \
# 0              Doe        1990-01-01           male
# 1              Doe        1992-04-12         female
#
#                          profile.avatarUrl  ... preferences.language  \
# 0  https://example.com/avatars/johndoe.jpg  ...                   en
# 1  https://example.com/avatars/janedoe.jpg  ...                   fr
#
#   preferences.theme preferences.notifications.email  \
# 0              dark                            True
# 1             light                           False
#
# ...

# %% [markdown]
# Parquet File

# %%
pip install pyarrow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
parquet_path1="D:\\fasith\\house-price.parquet"

# %%
df_parquet= pd.read_parquet(parquet_path1, engine="pyarrow")

# %%
df_parquet
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df_parquet1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
parquet_path3="D:\\fasith\\weather.parquet"

# %%
df_parquet2 = pd.read_parquet(parquet_path3, engine="pyarrow")

# %%
df_parquet2
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4      6.3          NW
# 1       14.0     26.9       3.6          4.4      9.7         ENE
# 2       13.7     23.4       3.6          5.8      3.3          NW
# 3       13.3     15.5      39.8          7.2      9.1          NW
# 4        7.6     16.1       2.8          5.6     10.6         SSE
# ..       ...      ...       ...          ...      ...         ...
# 361      9.0     30.7       0.0          7.6     12.1         NNW
# 362      7.1     28.4       0.0         11.6     12.7           N
# 363     12.5     19.9       0.0          8.4      5.3         ESE
# 364     12.5     26.9       0.0          5.0      7.1          NW
# 365     12.3     30.2       0.0          6.0     12.6          NW
#
#     WindGustSpeed WindDir9am WindDir3pm WindSpeed9am  ...  Humidity3pm  \
# 0              30         SW         NW            6  ...           29
# ...
